# %%
# import statements
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.3.0 pyspark-shell'

from time import sleep
from kafka import KafkaConsumer
import datetime as dt
import matplotlib.pyplot as plt
import json
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# this line is needed for the inline display of graphs in Jupyter Notebook
# %matplotlib notebook

x, y, y2 = [], [], []
def init_plots():
    try:
        width = 9.5
        height = 6
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        fig.suptitle('Real-time uniform stream data visualization') # giving figure a title
        ax.set_xlabel('Time')
        ax.set_ylabel('Value')
        ax.set_ylim(0,110) 
        ax.set_yticks([0,20,40,60,80,100])
        fig.show() # displaying the figure
        fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))
    
def consume_messages(consumer, fig, ax):
    try:
        # container for x and y values
        global x
        global y
        global y2
        # print('Waiting for messages')
        for message in consumer.collect():
            print('*'* 40)
            print(message)
            print('*'* 40)
            data = message
            #data = str(message.value.decode('utf-8')).split(', ')
            x.append(data['created_at']) 
            y.append(min(y + [data['air_temperature_celcius']]))
            y2.append(max(y + [data['air_temperature_celcius']]))
            # print(y)
            # we start plotting only when we have 10 data points
        if len(y) >= 10:
            ax.clear()
            ax.plot(x, y)
            ax.plot(x, y2)
            ax.set_xlabel('Time')
            ax.set_ylabel('Value')
            ax.set_ylim(0,80) 
            ax.set_yticks([0,20,40,60,80,100])
            fig.canvas.draw()
            x.pop(0) # removing the item in the first position
            y.pop(0)
            y2.pop(0)
        #plt.close('all')
    except Exception as ex:
        print(str(ex))
    
if __name__ == '__main__':
    fig, ax = init_plots()
    topic = ['climate']
    n_secs = 5
    conf = SparkConf().setAppName("KafkaStreamProcessor")
    sc = SparkContext.getOrCreate()
    if sc is None:
        sc = SparkContext(conf=conf)
    sc.setLogLevel("WARN")
    ssc = StreamingContext(sc, n_secs)
    #Kafka Streaming object
    kafkaStream = KafkaUtils.createDirectStream(ssc,topic , {
            'bootstrap.servers':'localhost:9092', 
            })
    lines = kafkaStream.map(lambda x: json.loads(x[1]))
# lines.pprint()
    fore = lines.foreachRDD(lambda x: consume_messages(x, fig, ax))
    ssc.start()
    ssc.awaitTermination()
# Out:
# <img src="data:image/png;base64,..." width="949.76">
# ****************************************
# {'latitude': -37.1926, 'longitude': 143.8095, 'air_temperature_celcius': 8, 'relative_humidity': 36.3, 'windspeed_knots': 6.3, 'max_wind_speed': 13, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:18:16'}
# ****************************************
# ****************************************
# {'latitude': -37.8276, 'longitude': 142.7573, 'air_temperature_celcius': 9, 'relative_humidity': 42.1, 'windspeed_knots': 7.6, 'max_wind_speed': 12, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:18:21'}
# ****************************************
# ****************************************
# {'latitude': -37.401, 'longitude': 148.067, 'air_temperature_celcius': 13, 'relative_humidity': 42.5, 'windspeed_knots': 14, 'max_wind_speed': 19, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:18:26'}
# ****************************************
# ****************************************
# {'latitude': -35.961, 'longitude': 141.089, 'air_temperature_celcius': 5, 'relative_humidity': 34.9, 'windspeed_knots': 4.3, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00A', 'sender_id': 1, 'created_at': '18:18:31'}
# ****************************************
# ****************************************
# {'latitude': -35.325, 'longitude': 143.497, 'air_temperature_celcius': 13, 'relative_humidity': 48.5, 'windspeed_knots': 5.3, 'max_wind_speed': 11.1, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:18:36'}
# ****************************************
# ****************************************
# {'latitude': -37.469, 'longitude': 148.103, 'air_temperature_celcius': 10, 'relative_humidity': 47.1, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:18:41'}
# ****************************************
# ****************************************
# {'latitude': -37.611, 'longitude': 149.277, 'air_temperature_celcius': 18, 'relative_humidity': 49.4, 'windspeed_knots': 9.3, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:18:46'}
# ****************************************
# ****************************************
# {'latitude': -38.141, 'longitude': 143.183, 'air_temperature_celcius': 23, 'relative_humidity': 54.1, 'windspeed_knots': 5.7, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:18:51'}
# ****************************************
# ****************************************
# {'latitude': -37.6745, 'longitude': 142.9848, 'air_temperature_celcius': 15, 'relative_humidity': 44.5, 'windspeed_knots': 10.2, 'max_wind_speed': 14, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:18:56'}
# ****************************************
# ****************************************
# {'latitude': -36.952, 'longitude': 144.972, 'air_temperature_celcius': 21, 'relative_humidity': 57.3, 'windspeed_knots': 5.4, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:19:01'}
# ****************************************
# ****************************************
# {'latitude': -37.561, 'longitude': 148.032, 'air_temperature_celcius': 9, 'relative_humidity': 42.8, 'windspeed_knots': 9.3, 'max_wind_speed': 13, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:19:06'}
# ****************************************
# ****************************************
# {'latitude': -37.368, 'longitude': 148.05, 'air_temperature_celcius': 10, 'relative_humidity': 41.4, 'windspeed_knots': 9.4, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:19:11'}
# ****************************************
# ****************************************
# {'latitude': -38.5, 'longitude': 146.938, 'air_temperature_celcius': 7, 'relative_humidity': 40.7, 'windspeed_knots': 3.7, 'max_wind_speed': 7, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:19:16'}
# ****************************************
# ****************************************
# {'latitude': -34.965, 'longitude': 142.031, 'air_temperature_celcius': 20, 'relative_humidity': 62.6, 'windspeed_knots': 10.1, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:19:21'}
# ****************************************
# ****************************************
# {'latitude': -37.391, 'longitude': 148.066, 'air_temperature_celcius': 14, 'relative_humidity': 44.6, 'windspeed_knots': 7.7, 'max_wind_speed': 15.9, 'precipitation ': ' 0.03G', 'sender_id': 1, 'created_at': '18:19:26'}
# ****************************************
# ****************************************
# {'latitude': -37.0667, 'longitude': 143.0582, 'air_temperature_celcius': 11, 'relative_humidity': 39.7, 'windspeed_knots': 11.8, 'max_wind_speed': 19, 'precipitation ': ' 0.28G', 'sender_id': 1, 'created_at': '18:19:31'}
# ****************************************
# ****************************************
# {'latitude': -37.379, 'longitude': 148.126, 'air_temperature_celcius': 9, 'relative_humidity': 42.9, 'windspeed_knots': 8.9, 'max_wind_speed': 15.9, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:19:36'}
# ****************************************
# ****************************************
# {'latitude': -36.6686, 'longitude': 142.5195, 'air_temperature_celcius': 16, 'relative_humidity': 47, 'windspeed_knots': 12, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:19:41'}
# ****************************************
# ****************************************
# {'latitude': -36.9817, 'longitude': 143.5051, 'air_temperature_celcius': 14, 'relative_humidity': 44, 'windspeed_knots': 14.4, 'max_wind_speed': 23.9, 'precipitation ': ' 0.16G', 'sender_id': 1, 'created_at': '18:19:46'}
# ****************************************
# ****************************************
# {'latitude': -36.282, 'longitude': 146.157, 'air_temperature_celcius': 17, 'relative_humidity': 50.4, 'windspeed_knots': 11.9, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:19:51'}
# ****************************************
# ****************************************
# {'latitude': -36.3328, 'longitude': 146.0355, 'air_temperature_celcius': 7, 'relative_humidity': 37.2, 'windspeed_knots': 6.2, 'max_wind_speed': 16.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:19:56'}
# ****************************************
# ****************************************
# {'latitude': -36.827, 'longitude': 142.5446, 'air_temperature_celcius': 8, 'relative_humidity': 39.3, 'windspeed_knots': 4.7, 'max_wind_speed': 13, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:20:01'}
# ****************************************
# ****************************************
# {'latitude': -37.586, 'longitude': 141.271, 'air_temperature_celcius': 19, 'relative_humidity': 60.5, 'windspeed_knots': 7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.83G', 'sender_id': 1, 'created_at': '18:20:06'}
# ****************************************
# ****************************************
# {'latitude': -36.156, 'longitude': 143.568, 'air_temperature_celcius': 13, 'relative_humidity': 51.4, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:20:11'}
# ****************************************
# ****************************************
# {'latitude': -37.61, 'longitude': 149.296, 'air_temperature_celcius': 16, 'relative_humidity': 48.3, 'windspeed_knots': 14.4, 'max_wind_speed': 19, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:20:16'}
# ****************************************
# ****************************************
# {'latitude': -37.1405, 'longitude': 144.1375, 'air_temperature_celcius': 20, 'relative_humidity': 60.8, 'windspeed_knots': 10.4, 'max_wind_speed': 16.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:20:21'}
# ****************************************
# ****************************************
# {'latitude': -37.583, 'longitude': 149.316, 'air_temperature_celcius': 25, 'relative_humidity': 58.3, 'windspeed_knots': 12.2, 'max_wind_speed': 22, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:20:26'}
# ****************************************
# ****************************************
# {'latitude': -36.6732, 'longitude': 142.5162, 'air_temperature_celcius': 19, 'relative_humidity': 53.9, 'windspeed_knots': 8.3, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:20:31'}
# ****************************************
# ****************************************
# {'latitude': -37.45, 'longitude': 148.126, 'air_temperature_celcius': 11, 'relative_humidity': 40.5, 'windspeed_knots': 13.4, 'max_wind_speed': 26, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:20:36'}
# ****************************************
# ****************************************
# {'latitude': -36.098, 'longitude': 143.74, 'air_temperature_celcius': 17, 'relative_humidity': 59.3, 'windspeed_knots': 4.2, 'max_wind_speed': 7, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:20:41'}
# ****************************************
# ****************************************
# {'latitude': -37.47, 'longitude': 148.089, 'air_temperature_celcius': 11, 'relative_humidity': 46.4, 'windspeed_knots': 6.5, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:20:46'}
# ****************************************
# ****************************************
# {'latitude': -36.7685, 'longitude': 142.7134, 'air_temperature_celcius': 14, 'relative_humidity': 48.2, 'windspeed_knots': 12.5, 'max_wind_speed': 19, 'precipitation ': ' 0.03G', 'sender_id': 1, 'created_at': '18:20:51'}
# ****************************************
# ****************************************
# {'latitude': -37.453, 'longitude': 148.111, 'air_temperature_celcius': 11, 'relative_humidity': 45.3, 'windspeed_knots': 10.6, 'max_wind_speed': 16.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:20:56'}
# ****************************************
# ****************************************
# {'latitude': -37.287, 'longitude': 144.392, 'air_temperature_celcius': 12, 'relative_humidity': 48.2, 'windspeed_knots': 7.3, 'max_wind_speed': 11.1, 'precipitation ': ' 0.03G', 'sender_id': 1, 'created_at': '18:21:01'}
# ****************************************
# ****************************************
# {'latitude': -36.293, 'longitude': 146.148, 'air_temperature_celcius': 16, 'relative_humidity': 50.8, 'windspeed_knots': 5.8, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:21:06'}
# ****************************************
# ****************************************
# {'latitude': -34.282, 'longitude': 142.121, 'air_temperature_celcius': 15, 'relative_humidity': 49.1, 'windspeed_knots': 9.6, 'max_wind_speed': 16.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:21:11'}
# ****************************************
# ****************************************
# {'latitude': -37.559, 'longitude': 148.037, 'air_temperature_celcius': 9, 'relative_humidity': 41.1, 'windspeed_knots': 12.7, 'max_wind_speed': 19, 'precipitation ': ' 0.24G', 'sender_id': 1, 'created_at': '18:21:16'}
# ****************************************
# ****************************************
# {'latitude': -37.294, 'longitude': 141.232, 'air_temperature_celcius': 12, 'relative_humidity': 49, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:21:21'}
# ****************************************
# ****************************************
# {'latitude': -36.6851, 'longitude': 141.6125, 'air_temperature_celcius': 17, 'relative_humidity': 59, 'windspeed_knots': 9.4, 'max_wind_speed': 15, 'precipitation ': ' 0.75G', 'sender_id': 1, 'created_at': '18:21:26'}
# ****************************************
# ****************************************
# {'latitude': -36.0714, 'longitude': 145.7665, 'air_temperature_celcius': 18, 'relative_humidity': 54.6, 'windspeed_knots': 12, 'max_wind_speed': 25.1, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:21:31'}
# ****************************************
# ****************************************
# {'latitude': -36.5794, 'longitude': 142.5959, 'air_temperature_celcius': 24, 'relative_humidity': 51.8, 'windspeed_knots': 7.9, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:21:36'}
# ****************************************
# ****************************************
# {'latitude': -37.478, 'longitude': 148.117, 'air_temperature_celcius': 11, 'relative_humidity': 43.9, 'windspeed_knots': 11.2, 'max_wind_speed': 16.9, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:21:41'}
# ****************************************
# ****************************************
# {'latitude': -38.116, 'longitude': 143.818, 'air_temperature_celcius': 10, 'relative_humidity': 46.8, 'windspeed_knots': 5.3, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:21:46'}
# ****************************************
# ****************************************
# {'latitude': -36.1462, 'longitude': 145.2096, 'air_temperature_celcius': 10, 'relative_humidity': 43.6, 'windspeed_knots': 9.7, 'max_wind_speed': 14, 'precipitation ': ' 0.20G', 'sender_id': 1, 'created_at': '18:21:51'}
# ****************************************
# ****************************************
# {'latitude': -36.9364, 'longitude': 143.4996, 'air_temperature_celcius': 14, 'relative_humidity': 41.7, 'windspeed_knots': 12.3, 'max_wind_speed': 18.1, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:21:56'}
# ****************************************
# ****************************************
# {'latitude': -37.3583, 'longitude': 143.0203, 'air_temperature_celcius': 13, 'relative_humidity': 43.3, 'windspeed_knots': 9.4, 'max_wind_speed': 14, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:22:01'}
# ****************************************
# ****************************************
# {'latitude': -38.226, 'longitude': 147.167, 'air_temperature_celcius': 10, 'relative_humidity': 43.7, 'windspeed_knots': 7.2, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:06'}
# ****************************************
# ****************************************
# {'latitude': -36.275, 'longitude': 146.154, 'air_temperature_celcius': 18, 'relative_humidity': 53.3, 'windspeed_knots': 7.9, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:11'}
# ****************************************
# ****************************************
# {'latitude': -36.3096, 'longitude': 142.7722, 'air_temperature_celcius': 24, 'relative_humidity': 56.8, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:16'}
# ****************************************
# ****************************************
# {'latitude': -37.457, 'longitude': 148.143, 'air_temperature_celcius': 9, 'relative_humidity': 39, 'windspeed_knots': 5.6, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:22:21'}
# ****************************************
# ****************************************
# {'latitude': -37.598, 'longitude': 149.29, 'air_temperature_celcius': 18, 'relative_humidity': 53.5, 'windspeed_knots': 8.8, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:26'}
# ****************************************
# ****************************************
# {'latitude': -37.6767, 'longitude': 142.9892, 'air_temperature_celcius': 18, 'relative_humidity': 53.8, 'windspeed_knots': 6.7, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:31'}
# ****************************************
# ****************************************
# {'latitude': -37.249, 'longitude': 143.413, 'air_temperature_celcius': 14, 'relative_humidity': 47.9, 'windspeed_knots': 5.3, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:36'}
# ****************************************
# ****************************************
# {'latitude': -36.764, 'longitude': 144.165, 'air_temperature_celcius': 14, 'relative_humidity': 52.4, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:41'}
# ****************************************
# ****************************************
# {'latitude': -37.46, 'longitude': 148.113, 'air_temperature_celcius': 11, 'relative_humidity': 44.2, 'windspeed_knots': 8.7, 'max_wind_speed': 15.9, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:22:46'}
# ****************************************
# ****************************************
# {'latitude': -36.6296, 'longitude': 142.5191, 'air_temperature_celcius': 28, 'relative_humidity': 49.9, 'windspeed_knots': 11, 'max_wind_speed': 19, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:51'}
# ****************************************
# ****************************************
# {'latitude': -37.333, 'longitude': 148.099, 'air_temperature_celcius': 10, 'relative_humidity': 35.6, 'windspeed_knots': 14.5, 'max_wind_speed': 20, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:22:56'}
# ****************************************
# ****************************************
# {'latitude': -36.942, 'longitude': 143.282, 'air_temperature_celcius': 25, 'relative_humidity': 58.3, 'windspeed_knots': 7.1, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:01'}
# ****************************************
# ****************************************
# {'latitude': -37.805, 'longitude': 144.15, 'air_temperature_celcius': 12, 'relative_humidity': 45, 'windspeed_knots': 10.5, 'max_wind_speed': 16.9, 'precipitation ': ' 0.16G', 'sender_id': 1, 'created_at': '18:23:06'}
# ****************************************
# ****************************************
# {'latitude': -36.3114, 'longitude': 142.7605, 'air_temperature_celcius': 28, 'relative_humidity': 56.7, 'windspeed_knots': 9.3, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:11'}
# ****************************************
# ****************************************
# {'latitude': -37.444, 'longitude': 148.101, 'air_temperature_celcius': 9, 'relative_humidity': 42, 'windspeed_knots': 4.6, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:16'}
# ****************************************
# ****************************************
# {'latitude': -36.009, 'longitude': 143.185, 'air_temperature_celcius': 28, 'relative_humidity': 48.3, 'windspeed_knots': 11.9, 'max_wind_speed': 22, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:21'}
# ****************************************
# ****************************************
# {'latitude': -37.856, 'longitude': 143.416, 'air_temperature_celcius': 15, 'relative_humidity': 53.7, 'windspeed_knots': 6.8, 'max_wind_speed': 11.1, 'precipitation ': ' 0.51G', 'sender_id': 1, 'created_at': '18:23:26'}
# ****************************************
# ****************************************
# {'latitude': -36.275, 'longitude': 142.785, 'air_temperature_celcius': 6, 'relative_humidity': 30.8, 'windspeed_knots': 5.7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:31'}
# ****************************************
# ****************************************
# {'latitude': -37.497, 'longitude': 147.266, 'air_temperature_celcius': 10, 'relative_humidity': 41, 'windspeed_knots': 14.1, 'max_wind_speed': 20, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:23:36'}
# ****************************************
# ****************************************
# {'latitude': -36.404, 'longitude': 142.5467, 'air_temperature_celcius': 25, 'relative_humidity': 60.9, 'windspeed_knots': 6.3, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:41'}
# ****************************************
# ****************************************
# {'latitude': -36.7179, 'longitude': 142.2536, 'air_temperature_celcius': 11, 'relative_humidity': 40.4, 'windspeed_knots': 9.2, 'max_wind_speed': 15, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:23:46'}
# ****************************************
# ****************************************
# {'latitude': -37.46, 'longitude': 148.102, 'air_temperature_celcius': 10, 'relative_humidity': 46.3, 'windspeed_knots': 4.6, 'max_wind_speed': 8, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:23:51'}
# ****************************************
# ****************************************
# {'latitude': -37.63, 'longitude': 149.232, 'air_temperature_celcius': 18, 'relative_humidity': 57, 'windspeed_knots': 7.4, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:23:56'}
# ****************************************
# ****************************************
# {'latitude': -36.251, 'longitude': 142.5651, 'air_temperature_celcius': 17, 'relative_humidity': 53.6, 'windspeed_knots': 7.6, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:24:01'}
# ****************************************
# ****************************************
# {'latitude': -37.434, 'longitude': 148.123, 'air_temperature_celcius': 14, 'relative_humidity': 43.7, 'windspeed_knots': 17, 'max_wind_speed': 27, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:24:06'}
# ****************************************
# ****************************************
# {'latitude': -35.6374, 'longitude': 142.3787, 'air_temperature_celcius': 14, 'relative_humidity': 41.6, 'windspeed_knots': 13.1, 'max_wind_speed': 18.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:24:11'}
# ****************************************
# ****************************************
# {'latitude': -37.692, 'longitude': 143.593, 'air_temperature_celcius': 14, 'relative_humidity': 45.8, 'windspeed_knots': 6.5, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:24:16'}
# ****************************************
# ****************************************
# {'latitude': -37.8147, 'longitude': 143.1062, 'air_temperature_celcius': 17, 'relative_humidity': 46.4, 'windspeed_knots': 9.5, 'max_wind_speed': 20, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:24:21'}
# ****************************************
# ****************************************
# {'latitude': -36.3674, 'longitude': 143.7295, 'air_temperature_celcius': 15, 'relative_humidity': 48.7, 'windspeed_knots': 8.5, 'max_wind_speed': 20, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:24:26'}
# ****************************************
# ****************************************
# {'latitude': -36.984, 'longitude': 148.25, 'air_temperature_celcius': 10, 'relative_humidity': 39.9, 'windspeed_knots': 12.6, 'max_wind_speed': 16.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:24:31'}
# ****************************************
# ****************************************
# {'latitude': -37.8072, 'longitude': 142.2406, 'air_temperature_celcius': 12, 'relative_humidity': 44.2, 'windspeed_knots': 6.2, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:24:36'}
# ****************************************
# ****************************************
# {'latitude': -36.778, 'longitude': 145.1635, 'air_temperature_celcius': 17, 'relative_humidity': 46.3, 'windspeed_knots': 11.7, 'max_wind_speed': 20, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:24:41'}
# ****************************************
# ****************************************
# {'latitude': -38.167, 'longitude': 143.841, 'air_temperature_celcius': 21, 'relative_humidity': 58.1, 'windspeed_knots': 5.3, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:24:46'}
# ****************************************
# ****************************************
# {'latitude': -35.889, 'longitude': 145.614, 'air_temperature_celcius': 14, 'relative_humidity': 49.2, 'windspeed_knots': 10.5, 'max_wind_speed': 20, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:24:51'}
# ****************************************
# ****************************************
# {'latitude': -37.087, 'longitude': 145.363, 'air_temperature_celcius': 13, 'relative_humidity': 49.4, 'windspeed_knots': 3.8, 'max_wind_speed': 9.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:24:56'}
# ****************************************
# ****************************************
# {'latitude': -37.719, 'longitude': 142.154, 'air_temperature_celcius': 13, 'relative_humidity': 47, 'windspeed_knots': 7.9, 'max_wind_speed': 15, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:25:01'}
# ****************************************
# ****************************************
# {'latitude': -37.642, 'longitude': 149.263, 'air_temperature_celcius': 20, 'relative_humidity': 55.8, 'windspeed_knots': 10.5, 'max_wind_speed': 15.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:25:06'}
# ****************************************
# ****************************************
# {'latitude': -37.329, 'longitude': 143.136, 'air_temperature_celcius': 21, 'relative_humidity': 47, 'windspeed_knots': 13.2, 'max_wind_speed': 20, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:25:11'}
# ****************************************
# ****************************************
# {'latitude': -37.461, 'longitude': 148.103, 'air_temperature_celcius': 10, 'relative_humidity': 45.9, 'windspeed_knots': 3.2, 'max_wind_speed': 7, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:25:16'}
# ****************************************
# ****************************************
# {'latitude': -36.701, 'longitude': 142.538, 'air_temperature_celcius': 18, 'relative_humidity': 61.5, 'windspeed_knots': 5.5, 'max_wind_speed': 11.1, 'precipitation ': ' 0.28G', 'sender_id': 1, 'created_at': '18:25:21'}
# ****************************************
# ****************************************
# {'latitude': -37.618, 'longitude': 143.0013, 'air_temperature_celcius': 14, 'relative_humidity': 36, 'windspeed_knots': 15.9, 'max_wind_speed': 22, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:25:26'}
# ****************************************
# ****************************************
# {'latitude': -37.247, 'longitude': 141.278, 'air_temperature_celcius': 14, 'relative_humidity': 47.4, 'windspeed_knots': 7.1, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:25:31'}
# ****************************************
# ****************************************
# {'latitude': -37.062, 'longitude': 141.373, 'air_temperature_celcius': 22, 'relative_humidity': 46.8, 'windspeed_knots': 8, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:25:36'}
# ****************************************
# ****************************************
# {'latitude': -36.9194, 'longitude': 143.6131, 'air_temperature_celcius': 19, 'relative_humidity': 50.3, 'windspeed_knots': 7.7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:25:41'}
# ****************************************
# ****************************************
# {'latitude': -35.962, 'longitude': 143.791, 'air_temperature_celcius': 14, 'relative_humidity': 49.9, 'windspeed_knots': 6.8, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:25:46'}
# ****************************************
# ****************************************
# {'latitude': -37.406, 'longitude': 148.123, 'air_temperature_celcius': 12, 'relative_humidity': 44.7, 'windspeed_knots': 11.4, 'max_wind_speed': 18.1, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:25:51'}
# ****************************************
# ****************************************
# {'latitude': -36.4125, 'longitude': 143.1189, 'air_temperature_celcius': 12, 'relative_humidity': 47.9, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:25:56'}
# ****************************************
# ****************************************
# {'latitude': -37.213, 'longitude': 142.941, 'air_temperature_celcius': 23, 'relative_humidity': 61.9, 'windspeed_knots': 8, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:01'}
# ****************************************
# ****************************************
# {'latitude': -37.605, 'longitude': 149.302, 'air_temperature_celcius': 18, 'relative_humidity': 54.4, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:06'}
# ****************************************
# ****************************************
# {'latitude': -36.4274, 'longitude': 142.1944, 'air_temperature_celcius': 22, 'relative_humidity': 46.9, 'windspeed_knots': 12.9, 'max_wind_speed': 19, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:11'}
# ****************************************
# ****************************************
# {'latitude': -37.471, 'longitude': 148.091, 'air_temperature_celcius': 9, 'relative_humidity': 40.8, 'windspeed_knots': 6.7, 'max_wind_speed': 15, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:26:16'}
# ****************************************
# ****************************************
# {'latitude': -36.1002, 'longitude': 142.3405, 'air_temperature_celcius': 23, 'relative_humidity': 49.6, 'windspeed_knots': 6.3, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:21'}
# ****************************************
# ****************************************
# {'latitude': -36.8948, 'longitude': 142.3282, 'air_temperature_celcius': 9, 'relative_humidity': 41.2, 'windspeed_knots': 6.7, 'max_wind_speed': 13, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:26:26'}
# ****************************************
# ****************************************
# {'latitude': -34.5374, 'longitude': 141.7141, 'air_temperature_celcius': 8, 'relative_humidity': 40.8, 'windspeed_knots': 5.5, 'max_wind_speed': 9.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:26:31'}
# ****************************************
# ****************************************
# {'latitude': -37.644, 'longitude': 149.233, 'air_temperature_celcius': 22, 'relative_humidity': 58, 'windspeed_knots': 6.9, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:36'}
# ****************************************
# ****************************************
# {'latitude': -36.575, 'longitude': 146.6668, 'air_temperature_celcius': 18, 'relative_humidity': 53.6, 'windspeed_knots': 7.9, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:26:41'}
# ****************************************
# ****************************************
# {'latitude': -36.942, 'longitude': 143.292, 'air_temperature_celcius': 18, 'relative_humidity': 51.1, 'windspeed_knots': 8.1, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:46'}
# ****************************************
# ****************************************
# {'latitude': -37.485, 'longitude': 148.095, 'air_temperature_celcius': 11, 'relative_humidity': 45.4, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00A', 'sender_id': 1, 'created_at': '18:26:51'}
# ****************************************
# ****************************************
# {'latitude': -37.461, 'longitude': 148.105, 'air_temperature_celcius': 10, 'relative_humidity': 45.6, 'windspeed_knots': 4.5, 'max_wind_speed': 7, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:26:56'}
# ****************************************
# ****************************************
# {'latitude': -35.954, 'longitude': 141.076, 'air_temperature_celcius': 10, 'relative_humidity': 42.1, 'windspeed_knots': 9.4, 'max_wind_speed': 15, 'precipitation ': ' 0.13B', 'sender_id': 1, 'created_at': '18:27:01'}
# ****************************************
# ****************************************
# {'latitude': -37.7052, 'longitude': 144.6926, 'air_temperature_celcius': 17, 'relative_humidity': 52.7, 'windspeed_knots': 7.7, 'max_wind_speed': 14, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:27:06'}
# ****************************************
# ****************************************
# {'latitude': -36.4553, 'longitude': 142.8786, 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:27:11'}
# ****************************************
# ****************************************
# {'latitude': -36.341, 'longitude': 143.636, 'air_temperature_celcius': 16, 'relative_humidity': 47.5, 'windspeed_knots': 5.4, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:27:16'}
# ****************************************
# ****************************************
# {'latitude': -36.498, 'longitude': 144.877, 'air_temperature_celcius': 12, 'relative_humidity': 51.6, 'windspeed_knots': 3.4, 'max_wind_speed': 11.1, 'precipitation ': ' 0.05G', 'sender_id': 1, 'created_at': '18:27:21'}
# ****************************************
# ****************************************
# {'latitude': -36.0856, 'longitude': 144.233, 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 5.9, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:27:26'}
# ****************************************
# ****************************************
# {'latitude': -35.364, 'longitude': 141.063, 'air_temperature_celcius': 15, 'relative_humidity': 51.9, 'windspeed_knots': 6.6, 'max_wind_speed': 12, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:27:31'}
# ****************************************
# ****************************************
# {'latitude': -37.4437, 'longitude': 143.4924, 'air_temperature_celcius': 13, 'relative_humidity': 50.7, 'windspeed_knots': 6.1, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:27:36'}
# ****************************************
# ****************************************
# {'latitude': -37.375, 'longitude': 148.063, 'air_temperature_celcius': 10, 'relative_humidity': 43.5, 'windspeed_knots': 12, 'max_wind_speed': 16.9, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:27:41'}
# ****************************************
# ****************************************
# {'latitude': -37.293, 'longitude': 141.245, 'air_temperature_celcius': 10, 'relative_humidity': 45.7, 'windspeed_knots': 3.7, 'max_wind_speed': 8, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:27:46'}
# ****************************************
# ****************************************
# {'latitude': -36.096, 'longitude': 146.5016, 'air_temperature_celcius': 12, 'relative_humidity': 41, 'windspeed_knots': 12.9, 'max_wind_speed': 16.9, 'precipitation ': ' 0.16G', 'sender_id': 1, 'created_at': '18:27:51'}
# ****************************************
# ****************************************
# {'latitude': -36.779, 'longitude': 146.108, 'air_temperature_celcius': 13, 'relative_humidity': 42, 'windspeed_knots': 11.4, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:27:56'}
# ****************************************
# ****************************************
# {'latitude': -37.862, 'longitude': 144.175, 'air_temperature_celcius': 20, 'relative_humidity': 52.9, 'windspeed_knots': 17, 'max_wind_speed': 21, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:28:01'}
# ****************************************
# ****************************************
# {'latitude': -35.892, 'longitude': 145.62, 'air_temperature_celcius': 10, 'relative_humidity': 42.6, 'windspeed_knots': 8.9, 'max_wind_speed': 15, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:28:06'}
# ****************************************
# ****************************************
# {'latitude': -36.294, 'longitude': 146.149, 'air_temperature_celcius': 20, 'relative_humidity': 57.7, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:28:11'}
# ****************************************
# ****************************************
# {'latitude': -37.0046, 'longitude': 141.8047, 'air_temperature_celcius': 10, 'relative_humidity': 41.4, 'windspeed_knots': 6.9, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:28:16'}
# ****************************************
# ****************************************
# {'latitude': -36.3782, 'longitude': 143.7313, 'air_temperature_celcius': 17, 'relative_humidity': 44.9, 'windspeed_knots': 16.1, 'max_wind_speed': 27, 'precipitation ': ' 0.24G', 'sender_id': 1, 'created_at': '18:28:21'}
# ****************************************
# ****************************************
# {'latitude': -36.059, 'longitude': 143.7718, 'air_temperature_celcius': 18, 'relative_humidity': 53.8, 'windspeed_knots': 6.4, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:28:26'}
# ****************************************
# ****************************************
# {'latitude': -37.459, 'longitude': 148.092, 'air_temperature_celcius': 13, 'relative_humidity': 48.5, 'windspeed_knots': 7.1, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:28:31'}
# ****************************************
# ****************************************
# {'latitude': -37.637, 'longitude': 146.288, 'air_temperature_celcius': 31, 'relative_humidity': 61.9, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:28:36'}
# ****************************************
# ****************************************
# {'latitude': -37.863, 'longitude': 144.17, 'air_temperature_celcius': 18, 'relative_humidity': 57.5, 'windspeed_knots': 16.1, 'max_wind_speed': 21, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:28:41'}
# ****************************************
# ****************************************
# {'latitude': -37.434, 'longitude': 148.091, 'air_temperature_celcius': 9, 'relative_humidity': 40, 'windspeed_knots': 8.6, 'max_wind_speed': 15, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:28:46'}
# ****************************************
# ****************************************
# {'latitude': -36.5243, 'longitude': 142.0839, 'air_temperature_celcius': 9, 'relative_humidity': 43.9, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:28:51'}
# ****************************************
# ****************************************
# {'latitude': -37.886, 'longitude': 147.207, 'air_temperature_celcius': 19, 'relative_humidity': 54.3, 'windspeed_knots': 5.9, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:28:56'}
# ****************************************
# ****************************************
# {'latitude': -37.332, 'longitude': 148.091, 'air_temperature_celcius': 8, 'relative_humidity': 39.3, 'windspeed_knots': 7.7, 'max_wind_speed': 14, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:29:01'}
# ****************************************
# ****************************************
# {'latitude': -37.978, 'longitude': 145.623, 'air_temperature_celcius': 21, 'relative_humidity': 59.5, 'windspeed_knots': 12.4, 'max_wind_speed': 21, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:06'}
# ****************************************
# ****************************************
# {'latitude': -37.608, 'longitude': 149.292, 'air_temperature_celcius': 15, 'relative_humidity': 44.6, 'windspeed_knots': 9.7, 'max_wind_speed': 12, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:29:11'}
# ****************************************
# ****************************************
# {'latitude': -36.152, 'longitude': 143.578, 'air_temperature_celcius': 15, 'relative_humidity': 56.1, 'windspeed_knots': 5.1, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:16'}
# ****************************************
# ****************************************
# {'latitude': -37.57, 'longitude': 148.034, 'air_temperature_celcius': 11, 'relative_humidity': 40.4, 'windspeed_knots': 19.3, 'max_wind_speed': 26, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:29:21'}
# ****************************************
# ****************************************
# {'latitude': -37.606, 'longitude': 149.312, 'air_temperature_celcius': 16, 'relative_humidity': 51, 'windspeed_knots': 6, 'max_wind_speed': 13, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:29:26'}
# ****************************************
# ****************************************
# {'latitude': -37.245, 'longitude': 143.426, 'air_temperature_celcius': 10, 'relative_humidity': 47, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:31'}
# ****************************************
# ****************************************
# {'latitude': -37.242, 'longitude': 141.153, 'air_temperature_celcius': 12, 'relative_humidity': 42.8, 'windspeed_knots': 12.1, 'max_wind_speed': 19, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:29:36'}
# ****************************************
# ****************************************
# {'latitude': -37.946, 'longitude': 144.342, 'air_temperature_celcius': 21, 'relative_humidity': 54.9, 'windspeed_knots': 7.4, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:41'}
# ****************************************
# ****************************************
# {'latitude': -37.591, 'longitude': 149.33, 'air_temperature_celcius': 16, 'relative_humidity': 46.7, 'windspeed_knots': 10, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:46'}
# ****************************************
# ****************************************
# {'latitude': -37.469, 'longitude': 148.125, 'air_temperature_celcius': 14, 'relative_humidity': 48.4, 'windspeed_knots': 7.5, 'max_wind_speed': 13, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:29:51'}
# ****************************************
# ****************************************
# {'latitude': -36.3334, 'longitude': 141.1515, 'air_temperature_celcius': 22, 'relative_humidity': 55.5, 'windspeed_knots': 10.3, 'max_wind_speed': 19, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:29:56'}
# ****************************************
# ****************************************
# {'latitude': -36.0459, 'longitude': 143.8907, 'air_temperature_celcius': 21, 'relative_humidity': 58.7, 'windspeed_knots': 7.8, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:30:01'}
# ****************************************
# ****************************************
# {'latitude': -36.6312, 'longitude': 142.5058, 'air_temperature_celcius': 17, 'relative_humidity': 52.5, 'windspeed_knots': 5.7, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:30:06'}
# ****************************************
# ****************************************
# {'latitude': -36.2127, 'longitude': 141.4938, 'air_temperature_celcius': 23, 'relative_humidity': 58.8, 'windspeed_knots': 8.8, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:30:11'}
# ****************************************
# ****************************************
# {'latitude': -37.376, 'longitude': 148.042, 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 5.5, 'max_wind_speed': 8, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:30:16'}
# ****************************************
# ****************************************
# {'latitude': -37.926, 'longitude': 144.0898, 'air_temperature_celcius': 15, 'relative_humidity': 51, 'windspeed_knots': 9, 'max_wind_speed': 13, 'precipitation ': ' 1.26G', 'sender_id': 1, 'created_at': '18:30:21'}
# ****************************************
# ****************************************
# {'latitude': -36.9085, 'longitude': 141.2821, 'air_temperature_celcius': 15, 'relative_humidity': 47.3, 'windspeed_knots': 8.6, 'max_wind_speed': 22.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:30:26'}
# ****************************************
# ****************************************
# {'latitude': -37.856, 'longitude': 143.416, 'air_temperature_celcius': 14, 'relative_humidity': 51, 'windspeed_knots': 9.1, 'max_wind_speed': 12, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:30:31'}
# ****************************************
# ****************************************
# {'latitude': -37.6, 'longitude': 149.325, 'air_temperature_celcius': 16, 'relative_humidity': 48.1, 'windspeed_knots': 9.3, 'max_wind_speed': 12, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:30:36'}
# ****************************************
# ****************************************
# {'latitude': -37.6008, 'longitude': 143.0558, 'air_temperature_celcius': 15, 'relative_humidity': 44.8, 'windspeed_knots': 8.3, 'max_wind_speed': 19, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:30:41'}
# ****************************************
# ****************************************
# {'latitude': -37.749, 'longitude': 148.297, 'air_temperature_celcius': 17, 'relative_humidity': 52.6, 'windspeed_knots': 10.3, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:30:46'}
# ****************************************
# ****************************************
# {'latitude': -36.7084, 'longitude': 142.7354, 'air_temperature_celcius': 13, 'relative_humidity': 44.1, 'windspeed_knots': 12.9, 'max_wind_speed': 19, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:30:51'}
# ****************************************
# ****************************************
# {'latitude': -36.0279, 'longitude': 146.0244, 'air_temperature_celcius': 24, 'relative_humidity': 60.1, 'windspeed_knots': 8, 'max_wind_speed': 13, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:30:56'}
# ****************************************
# ****************************************
# {'latitude': -37.406, 'longitude': 148.088, 'air_temperature_celcius': 12, 'relative_humidity': 43.9, 'windspeed_knots': 12, 'max_wind_speed': 15.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:31:01'}
# ****************************************
# ****************************************
# {'latitude': -37.858, 'longitude': 143.428, 'air_temperature_celcius': 13, 'relative_humidity': 50.4, 'windspeed_knots': 7.9, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:31:06'}
# ****************************************
# ****************************************
# {'latitude': -37.367, 'longitude': 148.04, 'air_temperature_celcius': 12, 'relative_humidity': 47.6, 'windspeed_knots': 9.1, 'max_wind_speed': 13, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:31:11'}
# ****************************************
# ****************************************
# {'latitude': -36.758, 'longitude': 145.19, 'air_temperature_celcius': 20, 'relative_humidity': 58.4, 'windspeed_knots': 6.1, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:31:16'}
# ****************************************
# ****************************************
# {'latitude': -38.498, 'longitude': 146.95, 'air_temperature_celcius': 5, 'relative_humidity': 38.6, 'windspeed_knots': 1.8, 'max_wind_speed': 5.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:31:21'}
# ****************************************
# ****************************************
# {'latitude': -37.465, 'longitude': 148.153, 'air_temperature_celcius': 11, 'relative_humidity': 43.5, 'windspeed_knots': 13.1, 'max_wind_speed': 21, 'precipitation ': ' 0.24G', 'sender_id': 1, 'created_at': '18:31:26'}
# ****************************************
# ****************************************
# ...
# ****************************************
# ****************************************
# {'latitude': -38.495, 'longitude': 146.944, 'air_temperature_celcius': 8, 'relative_humidity': 44.6, 'windspeed_knots': 3.9, 'max_wind_speed': 8, 'precipitation ': ' 0.39G', 'sender_id': 1, 'created_at': '18:32:56'}
# ****************************************
# ****************************************
# {'latitude': -37.399, 'longitude': 148.081, 'air_temperature_celcius': 14, 'relative_humidity': 49.9, 'windspeed_knots': 13.7, 'max_wind_speed': 22, 'precipitation ': ' 0.03G', 'sender_id': 1, 'created_at': '18:33:01'}
# ****************************************
# ****************************************
# {'latitude': -37.335, 'longitude': 148.064, 'air_temperature_celcius': 8, 'relative_humidity': 41, 'windspeed_knots': 11, 'max_wind_speed': 16.9, 'precipitation ': ' 0.47G', 'sender_id': 1, 'created_at': '18:33:06'}
# ****************************************
# ****************************************
# {'latitude': -37.609, 'longitude': 149.32, 'air_temperature_celcius': 16, 'relative_humidity': 48.3, 'windspeed_knots': 9.4, 'max_wind_speed': 14, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:33:11'}
# ****************************************
# ****************************************
# {'latitude': -37.384, 'longitude': 149.336, 'air_temperature_celcius': 16, 'relative_humidity': 48.9, 'windspeed_knots': 5.4, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:33:16'}
# ****************************************
# ****************************************
# {'latitude': -36.5507, 'longitude': 142.5788, 'air_temperature_celcius': 17, 'relative_humidity': 51.2, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:33:21'}
# ****************************************
# ****************************************
# {'latitude': -37.091, 'longitude': 145.362, 'air_temperature_celcius': 12, 'relative_humidity': 48.8, 'windspeed_knots': 4.2, 'max_wind_speed': 7, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:33:26'}
# ****************************************
# ****************************************
# {'latitude': -36.358, 'longitude': 143.113, 'air_temperature_celcius': 21, 'relative_humidity': 58.8, 'windspeed_knots': 8.8, 'max_wind_speed': 22.9, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:33:31'}
# ****************************************
# ****************************************
# {'latitude': -37.479, 'longitude': 143.358, 'air_temperature_celcius': 23, 'relative_humidity': 60.6, 'windspeed_knots': 10.1, 'max_wind_speed': 26, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:33:36'}
# ****************************************
# ****************************************
# {'latitude': -36.837, 'longitude': 142.0391, 'air_temperature_celcius': 19, 'relative_humidity': 55.8, 'windspeed_knots': 6, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:33:41'}
# ****************************************
# ****************************************
# {'latitude': -37.596, 'longitude': 149.319, 'air_temperature_celcius': 19, 'relative_humidity': 56.1, 'windspeed_knots': 6.9, 'max_wind_speed': 12, 'precipitation ': ' 0.00A', 'sender_id': 1, 'created_at': '18:33:46'}
# ****************************************
# ****************************************
# {'latitude': -37.461, 'longitude': 148.109, 'air_temperature_celcius': 14, 'relative_humidity': 50.7, 'windspeed_knots': 8.6, 'max_wind_speed': 13, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:33:51'}
# ****************************************
# ****************************************
# {'latitude': -37.327, 'longitude': 148.083, 'air_temperature_celcius': 10, 'relative_humidity': 44.8, 'windspeed_knots': 8.8, 'max_wind_speed': 14, 'precipitation ': ' 0.39G', 'sender_id': 1, 'created_at': '18:33:56'}
# ****************************************
# ****************************************
# {'latitude': -37.5268, 'longitude': 143.0551, 'air_temperature_celcius': 8, 'relative_humidity': 35, 'windspeed_knots': 14.4, 'max_wind_speed': 20, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:34:01'}
# ****************************************
# ****************************************
# {'latitude': -37.456, 'longitude': 148.11, 'air_temperature_celcius': 10, 'relative_humidity': 47.9, 'windspeed_knots': 4.1, 'max_wind_speed': 7, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:06'}
# ****************************************
# ****************************************
# {'latitude': -37.635, 'longitude': 149.303, 'air_temperature_celcius': 24, 'relative_humidity': 53.4, 'windspeed_knots': 9.9, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:11'}
# ****************************************
# ****************************************
# {'latitude': -35.957, 'longitude': 141.088, 'air_temperature_celcius': 9, 'relative_humidity': 42.4, 'windspeed_knots': 7.2, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:16'}
# ****************************************
# ****************************************
# {'latitude': -37.336, 'longitude': 148.073, 'air_temperature_celcius': 7, 'relative_humidity': 40.5, 'windspeed_knots': 8.1, 'max_wind_speed': 15, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:34:21'}
# ****************************************
# ****************************************
# {'latitude': -36.2032, 'longitude': 145.3025, 'air_temperature_celcius': 18, 'relative_humidity': 52, 'windspeed_knots': 7.1, 'max_wind_speed': 14, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:26'}
# ****************************************
# ****************************************
# {'latitude': -37.475, 'longitude': 143.365, 'air_temperature_celcius': 17, 'relative_humidity': 49.9, 'windspeed_knots': 12.2, 'max_wind_speed': 21, 'precipitation ': ' 0.24G', 'sender_id': 1, 'created_at': '18:34:31'}
# ****************************************
# ****************************************
# {'latitude': -37.415, 'longitude': 148.105, 'air_temperature_celcius': 12, 'relative_humidity': 47, 'windspeed_knots': 7.7, 'max_wind_speed': 15, 'precipitation ': ' 0.08G', 'sender_id': 1, 'created_at': '18:34:36'}
# ****************************************
# ****************************************
# {'latitude': -36.543, 'longitude': 141.138, 'air_temperature_celcius': 15, 'relative_humidity': 47.7, 'windspeed_knots': 5.9, 'max_wind_speed': 13, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:41'}
# ****************************************
# ****************************************
# {'latitude': -36.0966, 'longitude': 142.3635, 'air_temperature_celcius': 22, 'relative_humidity': 57, 'windspeed_knots': 8.5, 'max_wind_speed': 15, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:34:46'}
# ****************************************
# ****************************************
# {'latitude': -37.618, 'longitude': 149.281, 'air_temperature_celcius': 19, 'relative_humidity': 53.8, 'windspeed_knots': 9.2, 'max_wind_speed': 15, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:34:51'}
# ****************************************
# ****************************************
# {'latitude': -37.297, 'longitude': 144.384, 'air_temperature_celcius': 22, 'relative_humidity': 52.8, 'windspeed_knots': 9.1, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:34:56'}
# ****************************************
# ****************************************
# {'latitude': -36.098, 'longitude': 143.735, 'air_temperature_celcius': 17, 'relative_humidity': 58.1, 'windspeed_knots': 11.7, 'max_wind_speed': 19, 'precipitation ': ' 0.04G', 'sender_id': 1, 'created_at': '18:35:01'}
# ****************************************
# ****************************************
# {'latitude': -36.8264, 'longitude': 142.6138, 'air_temperature_celcius': 15, 'relative_humidity': 48.2, 'windspeed_knots': 14.7, 'max_wind_speed': 25.1, 'precipitation ': ' 0.43G', 'sender_id': 1, 'created_at': '18:35:06'}
# ****************************************
# ****************************************
# {'latitude': -37.384, 'longitude': 148.056, 'air_temperature_celcius': 9, 'relative_humidity': 43.2, 'windspeed_knots': 4.9, 'max_wind_speed': 8, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:35:11'}
# ****************************************
# ****************************************
# {'latitude': -37.45, 'longitude': 148.097, 'air_temperature_celcius': 9, 'relative_humidity': 41, 'windspeed_knots': 8.2, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:35:16'}
# ****************************************
# ****************************************
# {'latitude': -37.477, 'longitude': 143.352, 'air_temperature_celcius': 18, 'relative_humidity': 50.6, 'windspeed_knots': 6, 'max_wind_speed': 13, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:35:21'}
# ****************************************
# ****************************************
# {'latitude': -36.6859, 'longitude': 146.8907, 'air_temperature_celcius': 16, 'relative_humidity': 51.5, 'windspeed_knots': 8.7, 'max_wind_speed': 15, 'precipitation ': ' 0.02G', 'sender_id': 1, 'created_at': '18:35:26'}
# ****************************************
# ****************************************
# {'latitude': -37.758, 'longitude': 144.693, 'air_temperature_celcius': 20, 'relative_humidity': 58.8, 'windspeed_knots': 11.5, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:35:31'}
# ****************************************
# ****************************************
# {'latitude': -37.6, 'longitude': 149.297, 'air_temperature_celcius': 22, 'relative_humidity': 53.4, 'windspeed_knots': 10.9, 'max_wind_speed': 19, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:35:36'}
# ****************************************
# ****************************************
# {'latitude': -36.5548, 'longitude': 142.5237, 'air_temperature_celcius': 8, 'relative_humidity': 38.6, 'windspeed_knots': 12.8, 'max_wind_speed': 18.1, 'precipitation ': ' 0.31G', 'sender_id': 1, 'created_at': '18:35:41'}
# ****************************************
# ****************************************
# {'latitude': -37.331, 'longitude': 143.122, 'air_temperature_celcius': 19, 'relative_humidity': 44.2, 'windspeed_knots': 7.8, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:35:46'}
# ****************************************
# ****************************************
# {'latitude': -36.285, 'longitude': 146.151, 'air_temperature_celcius': 19, 'relative_humidity': 56.3, 'windspeed_knots': 5.8, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:35:51'}
# ****************************************
# ****************************************
# {'latitude': -38.912, 'longitude': 146.272, 'air_temperature_celcius': 18, 'relative_humidity': 53.3, 'windspeed_knots': 10.8, 'max_wind_speed': 15, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:35:56'}
# ****************************************
# ****************************************
# {'latitude': -36.279, 'longitude': 141.6716, 'air_temperature_celcius': 13, 'relative_humidity': 42.5, 'windspeed_knots': 8, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:01'}
# ****************************************
# ****************************************
# {'latitude': -37.634, 'longitude': 149.237, 'air_temperature_celcius': 16, 'relative_humidity': 48.4, 'windspeed_knots': 8.1, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:36:06'}
# ****************************************
# ****************************************
# {'latitude': -37.758, 'longitude': 148.721, 'air_temperature_celcius': 9, 'relative_humidity': 41.2, 'windspeed_knots': 9.8, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:11'}
# ****************************************
# ****************************************
# {'latitude': -37.453, 'longitude': 148.099, 'air_temperature_celcius': 10, 'relative_humidity': 45.7, 'windspeed_knots': 3.6, 'max_wind_speed': 7, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:36:16'}
# ****************************************
# ****************************************
# {'latitude': -35.953, 'longitude': 141.078, 'air_temperature_celcius': 12, 'relative_humidity': 47.2, 'windspeed_knots': 8.8, 'max_wind_speed': 15, 'precipitation ': ' 0.00G', 'sender_id': 1, 'created_at': '18:36:21'}
# ****************************************
# ****************************************
# {'latitude': -37.627, 'longitude': 149.261, 'air_temperature_celcius': 26, 'relative_humidity': 53.7, 'windspeed_knots': 8.7, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:26'}
# ****************************************
# ****************************************
# {'latitude': -37.472, 'longitude': 148.119, 'air_temperature_celcius': 15, 'relative_humidity': 49.9, 'windspeed_knots': 7.9, 'max_wind_speed': 13, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:36:31'}
# ****************************************
# ****************************************
# {'latitude': -37.954, 'longitude': 143.918, 'air_temperature_celcius': 20, 'relative_humidity': 59.7, 'windspeed_knots': 8.6, 'max_wind_speed': 15.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:36:36'}
# ****************************************
# ****************************************
# {'latitude': -37.633, 'longitude': 149.264, 'air_temperature_celcius': 16, 'relative_humidity': 50.9, 'windspeed_knots': 12.9, 'max_wind_speed': 21, 'precipitation ': ' 0.03G', 'sender_id': 1, 'created_at': '18:36:41'}
# ****************************************
# ****************************************
# {'latitude': -36.291, 'longitude': 146.159, 'air_temperature_celcius': 24, 'relative_humidity': 55.4, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:46'}
# ****************************************
# ****************************************
# {'latitude': -37.466, 'longitude': 148.1, 'air_temperature_celcius': 12, 'relative_humidity': 49.4, 'windspeed_knots': 4.4, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:51'}
# ****************************************
# ****************************************
# {'latitude': -37.466, 'longitude': 148.143, 'air_temperature_celcius': 17, 'relative_humidity': 48.7, 'windspeed_knots': 10.5, 'max_wind_speed': 15, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:36:56'}
# ****************************************
# ****************************************
# {'latitude': -37.238, 'longitude': 141.145, 'air_temperature_celcius': 8, 'relative_humidity': 41.6, 'windspeed_knots': 8.3, 'max_wind_speed': 15.9, 'precipitation ': ' 0.24G', 'sender_id': 1, 'created_at': '18:37:01'}
# ****************************************
# ****************************************
# {'latitude': -37.448, 'longitude': 148.114, 'air_temperature_celcius': 10, 'relative_humidity': 44.4, 'windspeed_knots': 5.6, 'max_wind_speed': 11.1, 'precipitation ': ' 0.12G', 'sender_id': 1, 'created_at': '18:37:06'}
# ****************************************
# ****************************************
# {'latitude': -36.8867, 'longitude': 142.1873, 'air_temperature_celcius': 14, 'relative_humidity': 39.3, 'windspeed_knots': 17.7, 'max_wind_speed': 30.9, 'precipitation ': ' 0.01G', 'sender_id': 1, 'created_at': '18:37:11'}
# ****************************************
# ****************************************
# {'latitude': -37.62, 'longitude': 149.294, 'air_temperature_celcius': 21, 'relative_humidity': 60.4, 'windspeed_knots': 6.8, 'max_wind_speed': 12, 'precipitation ': ' 0.00I', 'sender_id': 1, 'created_at': '18:37:16'}
# ****************************************

# %%
import gmplot
from pymongo import MongoClient

# Mongo Connection
client = MongoClient()
db = client.fit5148_db
collection = db.hamid
items = collection.find({},{"_id":0})


lats = []
longs = []
gmap = gmplot.GoogleMapPlotter(-37.452, 148.115, 16)
for item in items:
    for fire in item['Fire']:
        lats.append(fire['latitude'])
        longs.append(fire['longitude'])
        gmap.marker(fire['latitude'], fire['longitude'],'cornflowerblue',
                    title = 'air_temperature_celcius :'+ str(item['air_temperature_celcius']) + ' ' +
                    'relative_humidity :' + str(item['relative_humidity']) + ' ' +
                    'surface_temperature_celcius  :' + str(fire['surface_temperature_celcius']) + ' ' +
                    'confidence :' + str(fire['confidence']))
    
# This section has been implemented in windows
gmap.draw("mymap.html")
