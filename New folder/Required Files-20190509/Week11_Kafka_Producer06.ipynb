# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

 
def publish_message(producer_instance, topic_name, data):
    try:
        value_bytes = bytes(data, encoding='utf-8')
        producer_instance.send(topic_name, value=value_bytes)
        print('Message published successfully. ' + data)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Scenario061'
    print('Publishing records..')
    producer06 = connect_kafka_producer()

    
    for e in range(100):
        if e % 10 != 0:
            data = "data:" + str(random.randrange(0,100))
        else: # every 10th record will have missing data
            data = "data:" 
        publish_message(producer06, topic, data)
        sleep(1)
# Out:
# Publishing records..
# Message published successfully. data:
# Message published successfully. data:82
# Message published successfully. data:82
# Message published successfully. data:20
# Message published successfully. data:8
# Message published successfully. data:77
# Message published successfully. data:53
# Message published successfully. data:57
# Message published successfully. data:41
# Message published successfully. data:21
# Message published successfully. data:
# Message published successfully. data:90
# Message published successfully. data:74
# Message published successfully. data:46
# Message published successfully. data:4
# Message published successfully. data:85
# Message published successfully. data:63
# Message published successfully. data:35
# Message published successfully. data:10
# Message published successfully. data:93
# Message published successfully. data:
# Message published successfully. data:55
# Message published successfully. data:33
# Message published successfully. data:5
# Message published successfully. data:61
# Message published successfully. data:67
# Message published successfully. data:34
# Message published successfully. data:87
# Message published successfully. data:86
# Message published successfully. data:38
# Message published successfully. data:
# Message published successfully. data:49
# Message published successfully. data:58
# Message published successfully. data:41
# Message published successfully. data:6
# Message published successfully. data:61
# Message published successfully. data:34
# Message published successfully. data:64
# Message published successfully. data:80
# Message published successfully. data:85
# Message published successfully. data:
# Message published successfully. data:79
# Message published successfully. data:75
# Message published successfully. data:34
# Message published successfully. data:52
# Message published successfully. data:40
# Message published successfully. data:45
# Message published successfully. data:12
# Message published successfully. data:63
# Message published successfully. data:71
# Message published successfully. data:
# Message published successfully. data:3
# Message published successfully. data:64
# Message published successfully. data:0
# Message published successfully. data:71
# Message published successfully. data:3
# Message published successfully. data:72
# Message published successfully. data:80
# Message published successfully. data:64
# Message published successfully. data:65
# Message published successfully. data:
# Message published successfully. data:28
# Message published successfully. data:94
# Message published successfully. data:57
# Message published successfully. data:15
# Message published successfully. data:90
# Message published successfully. data:18
# Message published successfully. data:21
# Message published successfully. data:10
# Message published successfully. data:86
# Message published successfully. data:
# Message published successfully. data:74
# Message published successfully. data:54
# Message published successfully. data:37
# Message published successfully. data:17
# Message published successfully. data:27
# Message published successfully. data:21
# Message published successfully. data:71
# Message published successfully. data:95
# Message published successfully. data:60
# Message published successfully. data:
# Message published successfully. data:66
# Message published successfully. data:49
# Message published successfully. data:83
# Message published successfully. data:73
# Message published successfully. data:36
# Message published successfully. data:0
# Message published successfully. data:13
# Message published successfully. data:39
# Message published successfully. data:32
# Message published successfully. data:
# Message published successfully. data:61
# Message published successfully. data:36
# Message published successfully. data:78
# Message published successfully. data:23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-61ad9a837518> in <module>
#      40             data = "data:"
#      41         publish_message(producer06, topic, data)
# ---> 42         sleep(1)
#
# KeyboardInterrupt:
