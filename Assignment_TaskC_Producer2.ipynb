# %%
import csv
import json
import re
from pprint import pprint

def read_csv(file):
    """
    Read CSV files and load them into memory as a dictionary.

    Args:
        csvFile -- Location and the name of the csvFile( i.e C:/FireData.csv or FireData.csv which is
        located in the same folder as the *.ipynb file)
        
        format -- format of the file 

    Returns:
        csv_rows -- loaded data ready for processing
    
    """
    csv_rows = []
    # Regular expression to match negative and positive numbers
    # ^ = Start of string position
    # $ = End of the string
    # \d = Digit character class (0-9)
    # -? = Zero or one negative sign
    # \d+ = One or more digits
    # . = dot character
    pattern = re.compile(r'^-?\d+.\d+$')
    with open(file) as csvfile:
        # read the csv file by DictReader 
        reader = csv.DictReader(csvfile)
        title = reader.fieldnames
        for row in reader:
            temp = {}
            for i in range(len(title)):
                if row[title[i]].isdigit():
                    temp[title[i]] = int(row[title[i]])
                # Match the defined pattern for floates
                elif pattern.match(row[title[i]]):
                    temp[title[i]] = float(row[title[i]])
                else:
                    temp[title[i]]= row[title[i]]
            # adding relevant values to relevant keys and strip any space from both
            # add the dictionary to csv_rows
            csv_rows.append(temp)
    return csv_rows

hostspot_AQUA = read_csv('hotspot_AQUA_streaming.csv')

# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
    
    topic = 'hotspot_AQUA'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    database = hostspot_AQUA
    # Producer for Sensor 3 randomly.
    # Produces random time is between 10-30 sec
    for item in random.sample(database, len(database)):
        item['sender_id'] = 2
        item['created_at'] = dt.datetime.now().strftime("%X")
        data = dumps(item)
        publish_message(producer, topic, 'sender2', data)
        delay = random.randint(10, 30)
        print('Sleeping for {} seconds.'.format(delay))
        sleep(delay)
# Out:
# Publishing records..
# Exception in publishing message.
# KafkaTimeoutError: Failed to update metadata after 60.0 secs.
# Sleeping for 11 seconds.
# Exception in publishing message.
# KafkaTimeoutError: Failed to update metadata after 60.0 secs.
# Sleeping for 25 seconds.
# Exception in publishing message.
# KafkaTimeoutError: Failed to update metadata after 60.0 secs.
# Sleeping for 27 seconds.
# Message published successfully. Data: {"latitude": -36.1581, "longitude": 142.7434, "confidence": 65, "surface_temperature_celcius": 43, "sender_id": 2, "created_at": "18:06:53"}
# Sleeping for 25 seconds.
# Message published successfully. Data: {"latitude": -37.4352, "longitude": 143.1444, "confidence": 100, "surface_temperature_celcius": 96, "sender_id": 2, "created_at": "18:07:36"}
# Sleeping for 30 seconds.
# Message published successfully. Data: {"latitude": -36.786, "longitude": 141.4403, "confidence": 81, "surface_temperature_celcius": 55, "sender_id": 2, "created_at": "18:08:06"}
# Sleeping for 21 seconds.
# Message published successfully. Data: {"latitude": -37.996, "longitude": 146.3535, "confidence": 86, "surface_temperature_celcius": 41, "sender_id": 2, "created_at": "18:08:57"}
# Sleeping for 14 seconds.
# Message published successfully. Data: {"latitude": -36.941, "longitude": 143.268, "confidence": 80, "surface_temperature_celcius": 37, "sender_id": 2, "created_at": "18:09:41"}
# Sleeping for 16 seconds.
# Message published successfully. Data: {"latitude": -36.7531, "longitude": 141.3253, "confidence": 84, "surface_temperature_celcius": 78, "sender_id": 2, "created_at": "18:10:12"}
# Sleeping for 19 seconds.
# Message published successfully. Data: {"latitude": -37.4169, "longitude": 145.5926, "confidence": 89, "surface_temperature_celcius": 64, "sender_id": 2, "created_at": "18:10:31"}
# Sleeping for 27 seconds.
# Message published successfully. Data: {"latitude": -38.0525, "longitude": 143.64, "confidence": 65, "surface_temperature_celcius": 43, "sender_id": 2, "created_at": "18:11:28"}
# Sleeping for 24 seconds.
# Message published successfully. Data: {"latitude": -36.3526, "longitude": 146.3686, "confidence": 72, "surface_temperature_celcius": 47, "sender_id": 2, "created_at": "18:12:22"}
# Sleeping for 22 seconds.
# Message published successfully. Data: {"latitude": -36.6688, "longitude": 145.2635, "confidence": 73, "surface_temperature_celcius": 47, "sender_id": 2, "created_at": "18:13:14"}
# Sleeping for 17 seconds.
# Message published successfully. Data: {"latitude": -36.2929, "longitude": 142.9282, "confidence": 55, "surface_temperature_celcius": 39, "sender_id": 2, "created_at": "18:13:37"}
# Sleeping for 21 seconds.
# Message published successfully. Data: {"latitude": -37.6261, "longitude": 142.9447, "confidence": 85, "surface_temperature_celcius": 59, "sender_id": 2, "created_at": "18:13:58"}
# Sleeping for 22 seconds.
# Message published successfully. Data: {"latitude": -37.1992, "longitude": 146.2301, "confidence": 68, "surface_temperature_celcius": 60, "sender_id": 2, "created_at": "18:14:20"}
# Sleeping for 10 seconds.
# Message published successfully. Data: {"latitude": -37.087, "longitude": 145.363, "confidence": 91, "surface_temperature_celcius": 42, "sender_id": 2, "created_at": "18:14:30"}
# Sleeping for 15 seconds.
# Message published successfully. Data: {"latitude": -35.0821, "longitude": 142.4532, "confidence": 83, "surface_temperature_celcius": 57, "sender_id": 2, "created_at": "18:14:45"}
# Sleeping for 27 seconds.
# Message published successfully. Data: {"latitude": -35.2791, "longitude": 142.5659, "confidence": 63, "surface_temperature_celcius": 49, "sender_id": 2, "created_at": "18:15:12"}
# Sleeping for 10 seconds.
# Message published successfully. Data: {"latitude": -36
"surface_temperature_celcius": 42, "sender_id": 2, "created_at": "18:57:26"}
# Sleeping for 24 seconds.
# Message published successfully. Data: {"latitude": -36.9315, "longitude": 142.9519, "confidence": 80, "surface_temperature_celcius": 53, "sender_id": 2, "created_at": "18:57:50"}
# Sleeping for 13 seconds.
# Message published successfully. Data: {"latitude": -36.4005, "longitude": 144.0756, "confidence": 78, "surface_temperature_celcius": 51, "sender_id": 2, "created_at": "18:58:03"}
# Sleeping for 17 seconds.
# Message published successfully. Data: {"latitude": -37.8249, "longitude": 143.6174, "confidence": 100, "surface_temperature_celcius": 98, "sender_id": 2, "created_at": "18:58:20"}
# Sleeping for 29 seconds.
# Message published successfully. Data: {"latitude": -37.3333, "longitude": 143.8079, "confidence": 75, "surface_temperature_celcius": 48, "sender_id": 2, "created_at": "18:58:49"}
# Sleeping for 14 seconds.
# Message published successfully. Data: {"latitude": -36.6828, "longitude": 144.784, "confidence": 90, "surface_temperature_celcius": 66, "sender_id": 2, "created_at": "18:59:03"}
# Sleeping for 29 seconds.
# Message published successfully. Data: {"latitude": -37.4485, "longitude": 143.5041, "confidence": 81, "surface_temperature_celcius": 54, "sender_id": 2, "created_at": "18:59:32"}
# Sleeping for 21 seconds.
# Message published successfully. Data: {"latitude": -36.6833, "longitude": 141.6347, "confidence": 86, "surface_temperature_celcius": 61, "sender_id": 2, "created_at": "18:59:53"}
# Sleeping for 27 seconds.
# Message published successfully. Data: {"latitude": -36.6188, "longitude": 144.0402, "confidence": 69, "surface_temperature_celcius": 44, "sender_id": 2, "created_at": "19:00:20"}
# Sleeping for 27 seconds.
# Message published successfully. Data: {"latitude": -36.5418, "longitude": 144.666, "confidence": 70, "surface_temperature_celcius": 45, "sender_id": 2, "created_at": "19:00:47"}
# Sleeping for 28 seconds.
# Message published successfully. Data: {"latitude": -37.9257, "longitude": 143.4891, "confidence": 63, "surface_temperature_celcius": 54, "sender_id": 2, "created_at": "19:01:15"}
# Sleeping for 29 seconds.
# Message published successfully. Data: {"latitude": -36.272, "longitude": 145.5501, "confidence": 74, "surface_temperature_celcius": 48, "sender_id": 2, "created_at": "19:01:44"}
# Sleeping for 30 seconds.
# Message published successfully. Data: {"latitude": -36.3296, "longitude": 141.7522, "confidence": 63, "surface_temperature_celcius": 41, "sender_id": 2, "created_at": "19:02:14"}
# Sleeping for 23 seconds.
# Message published successfully. Data: {"latitude": -36.4347, "longitude": 143.5704, "confidence": 63, "surface_temperature_celcius": 42, "sender_id": 2, "created_at": "19:02:37"}
# Sleeping for 16 seconds.
# Message published successfully. Data: {"latitude": -36.6986, "longitude": 142.7259, "confidence": 86, "surface_temperature_celcius": 72, "sender_id": 2, "created_at": "19:02:53"}
# Sleeping for 28 seconds.
# Message published successfully. Data: {"latitude": -36.4858, "longitude": 142.0815, "confidence": 76, "surface_temperature_celcius": 50, "sender_id": 2, "created_at": "19:03:21"}
# Sleeping for 12 seconds.
# Message published successfully. Data: {"latitude": -37.8289, "longitude": 145.9315, "confidence": 75, "surface_temperature_celcius": 49, "sender_id": 2, "created_at": "19:03:33"}
# Sleeping for 26 seconds.
# Message published successfully. Data: {"latitude": -37.3632, "longitude": 145.8356, "confidence": 75, "surface_temperature_celcius": 53, "sender_id": 2, "created_at": "19:03:59"}
# Sleeping for 22 seconds.
# Message published successfully. Data: {"latitude": -37.8429, "longitude": 143.8366, "confidence": 100, "surface_temperature_celcius": 88, "sender_id": 2, "created_at": "19:04:21"}
# Sleeping for 25 seconds.
# Message published successfully. Data: {"latitude": -37.7851, "longitude": 141.4593, "confidence": 52, "surface_temperature_celcius": 38, "sender_id": 2, "created_at": "19:04:46"}
# Sleeping for 19 seconds.
# Message published successfully. Data: {"latitude": -36.6258, "longitude": 142.9987, "confidence": 64, "surface_temperature_celcius": 42, "sender_id": 2, "created_at": "19:05:05"}
# Sleeping for 25 seconds.
